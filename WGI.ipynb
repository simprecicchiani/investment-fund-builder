# %%
from fund import Fund

# %%
# https://whitegirlindex.com
stocks = [
    'AAPL',
    'CPRI',
    'DIS',
    'EL',
    'ETSY',
    'FB',
    'GOOS',
    'LRLCF',
    'LULU',
    'LVMUY',
    'NFLX',
    'PAWZ',
    'RVLV',
    'SBUX',
    'TGT',
    'TPR',
    'UBER',
    'ULTA']

WGI = Fund(stocks, '2020-03-27', 'eq', False, 6000)

# %%
WGI.nav.plot()
# Out:
# <AxesSubplot:>

# %%
WGI.benchmark('SPY').plot()
# Out:
# <AxesSubplot:>

# %%
(WGI.values.iloc[-1]/WGI.nav.iloc[-1]).sort_values(ascending=False)
# Out:
# Symbols
# RVLV     0.165513
# ETSY     0.117495
# CPRI     0.090747
# TGT      0.058555
# TPR      0.056859
# LULU     0.049220
# ULTA     0.048847
# LVMUY    0.046757
# AAPL     0.043464
# PAWZ     0.043042
# FB       0.039731
# EL       0.038644
# NFLX     0.038325
# GOOS     0.037006
# UBER     0.034307
# SBUX     0.033823
# DIS      0.031639
# LRLCF    0.026027
# Name: 2021-10-14 00:00:00, dtype: float64

# %%
(WGI.values.iloc[-1]).plot.pie()
# Out:
# <AxesSubplot:ylabel='2021-10-14 00:00:00'>
